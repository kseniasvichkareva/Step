# %% [markdown]
# <a href="https://colab.research.google.com/github/kseniasvichkareva/Step/blob/main/%D0%94%D0%9719.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('netflix_titles.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# Дубликатов нет

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df1 = pd.DataFrame({'ID':[1, 2, 3], 'Value': ['A', 'B', 'C']})
df2 = pd.DataFrame({'ID':[2, 3, 4], 'Value': [90, 85, 70]})

# %%
result=pd.merge(df1, df2, on='ID', how='inner')

# %%
result
# Out:
#    ID Value_x  Value_y
# 0   2       B       90
# 1   3       C       85

# %%
data1=data[['show_id', 'type']]
data2=data[['show_id', 'title']]
data1
# Out:
#      show_id     type
# 0         s1    Movie
# 1         s2  TV Show
# 2         s3  TV Show
# 3         s4  TV Show
# 4         s5  TV Show
# ...      ...      ...
# 8802   s8803    Movie
# 8803   s8804  TV Show
# 8804   s8805    Movie
# 8805   s8806    Movie
# 8806   s8807    Movie
#
# [8807 rows x 2 columns]

# %%
data2
# Out:
#      show_id                  title
# 0         s1   Dick Johnson Is Dead
# 1         s2          Blood & Water
# 2         s3              Ganglands
# 3         s4  Jailbirds New Orleans
# 4         s5           Kota Factory
# ...      ...                    ...
# 8802   s8803                 Zodiac
# 8803   s8804            Zombie Dumb
# 8804   s8805             Zombieland
# 8805   s8806                   Zoom
# 8806   s8807                 Zubaan
#
# [8807 rows x 2 columns]

# %%
result1=pd.merge(data1, data2, on='show_id', how='outer')
result1
# Out:
#      show_id     type                  title
# 0         s1    Movie   Dick Johnson Is Dead
# 1         s2  TV Show          Blood & Water
# 2         s3  TV Show              Ganglands
# 3         s4  TV Show  Jailbirds New Orleans
# 4         s5  TV Show           Kota Factory
# ...      ...      ...                    ...
# 8802   s8803    Movie                 Zodiac
# 8803   s8804  TV Show            Zombie Dumb
# 8804   s8805    Movie             Zombieland
# 8805   s8806    Movie                   Zoom
# 8806   s8807    Movie                 Zubaan
#
# [8807 rows x 3 columns]

# %%
import pandas as pd
data4 = pd.read_csv('global-energy-substitution.csv')

# %% [markdown]
# загрузила другой дата фрейм, тк в прошлом не было численных данных необходимых для нормировки

# %%
norma = normalize(data4, norm='l1', axis=1)
norma_data4=pd.DataFrame(norma, columns=data4.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-8609e55a8a1a> in <cell line: 1>()
# ----> 1 norma = normalize(data4, norm='l1', axis=1)
#       2 norma_data4=pd.DataFrame(norma, columns=data4.columns)
#
# NameError: name 'normalize' is not defined

# %%
df = pd.DataFrame({'Возраст':[20, 30, 40], 'Зарплата': [20000, 44000, 115000]})
normalized_df = normalize(data4, norm='l1', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-6c5b3d77eb76> in <cell line: 2>()
#       1 df = pd.DataFrame({'Возраст':[20, 30, 40], 'Зарплата': [20000, 44000, 115000]})
# ----> 2 normalized_df = normalize(data4, norm='l1', axis=1)
#
# NameError: name 'normalize' is not defined

# %% [markdown]
# Рустем, подскажите, в чем ошибка?
# Получилось нормировать только с помощью preprocessing

# %%
from sklearn import preprocessing

# %%
df = pd.DataFrame({'Возраст':[20, 30, 40], 'Зарплата': [20000, 44000, 115000]})
normalized_d = preprocessing.normalize(df, axis = 1)
normalized_df = pd.DataFrame(normalized_d, columns=df.columns)
normalized_df
# Out:
#     Возраст  Зарплата
# 0  0.001000       1.0
# 1  0.000682       1.0
# 2  0.000348       1.0

# %%
normalized_data4 = preprocessing.normalize(data4, axis = 1)
normalized_data4f = pd.DataFrame(normalized_data4, columns=data4.columns)
normalized_data4f
# Out:
#         Year  Other_renewables  Biofuels         Solar      Wind  Hydropower  \
# 0   0.045041          0.004810  0.001113  2.014922e-07  0.000002    0.126119
# 1   0.043558          0.005188  0.001269  4.097109e-07  0.000003    0.126032
# 2   0.042904          0.005256  0.001479  7.508108e-07  0.000004    0.126498
# 3   0.041997          0.005576  0.001781  9.494429e-07  0.000009    0.125439
# 4   0.040832          0.005804  0.001753  6.442884e-07  0.000012    0.123546
# 5   0.039545          0.005786  0.001782  5.997347e-07  0.000020    0.123426
# 6   0.038868          0.006299  0.001870  1.515218e-05  0.000153    0.120628
# 7   0.038507          0.006989  0.002064  2.222073e-05  0.000208    0.123526
# 8   0.038429          0.007273  0.002137  2.884041e-05  0.000233    0.126058
# 9   0.038173          0.007757  0.002085  2.644452e-05  0.000268    0.125143
# 10  0.038111          0.007998  0.002188  3.147730e-05  0.000323    0.132398
# ...

# %%
data5 = data.dropna
data5
# Out:
# <bound method DataFrame.dropna of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...
